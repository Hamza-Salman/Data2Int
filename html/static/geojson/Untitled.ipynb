# %%
import geopandas as gpd

# %%
geo_df = gpd.read_file('lfed000b16a_e.shp')
geo_df.head()
# Out:
#   FEDUID                    FEDNAME                   FEDENAME  \
# 0  24054                  Outremont                  Outremont
# 1  24055                   Papineau                   Papineau
# 2  24056       Pierrefonds--Dollard       Pierrefonds--Dollard
# 3  24057                    Pontiac                    Pontiac
# 4  24058  Portneuf--Jacques-Cartier  Portneuf--Jacques-Cartier
#
#                     FEDFNAME PRUID           PRNAME  \
# 0                  Outremont    24  Quebec / Québec
# 1                   Papineau    24  Quebec / Québec
# 2       Pierrefonds--Dollard    24  Quebec / Québec
# 3                    Pontiac    24  Quebec / Québec
# 4  Portneuf--Jacques-Cartier    24  Quebec / Québec
#
#                                             geometry
# 0  POLYGON ((7630425.660 1246238.620, 7630405.231...
# 1  POLYGON ((7627127.311 1251441.949, 7627138.831...
# 2  MULTIPOLYGON (((7617613.500 1240740.874, 76175...
# 3  POLYGON ((7417836.414 1448561.194, 7417214.306...
# ...

# %%
FEDNAME.plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-d83c1ef89004> in <module>
# ----> 1 FEDNAME.plot()
#       2 plt.show()
#
# NameError: name 'FEDNAME' is not defined

# %%
import matplotlib.pyplot as plt

# %%
geo_df.plot(cmap = 'jet', column = 'FEDNAME', figsize = (15, 15))
plt.show()
